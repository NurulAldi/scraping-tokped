# %%
import pandas as pd
from datetime import datetime
import re

# %%
df = pd.read_json("../data/raw/hasil_tokopedia_scrap.json")
print("Jumlah data mentah: ", len(df))
df.head()
# Out:
# Jumlah data mentah:  3120
#                                                 Nama    Harga Rating  \
# 0  Headset / Headphone Gaming Rexus S6 / S 6 Pro ...   425000    5.0
# 1  Rexus M2 Headset Wireless Bluetooth Headphone ...   189000    5.0
# 2  REXUS RX S9 PRO Headset Headphone Earphone Wir...   475000    5.0
# 3  SONY WH-ULT900N ULT Wear Wireless Headphone Bl...  2111111    5.0
# 4  Philips TAA1708 / TAA 1708 16mm Driver Bluetoo...   239000    5.0
#
#                   Toko         Lokasi  \
# 0  BintangRayaKomputer  Jakarta Pusat
# 1        Risc Computer      Surakarta
# 2        Risc Computer      Surakarta
# 3   ATI OFFICIAL STORE       Surabaya
# 4        Starcomp Solo  Kab. Banyumas
#
#                                                  URL
# 0  https://www.tokopedia.com/bintangrayacom/heads...
# 1  https://www.tokopedia.com/risccomputer/rexus-m...
# 2  https://www.tokopedia.com/risccomputer/rexus-r...
# 3  https://www.tokopedia.com/ati/sony-wh-ult900n-...
# 4  https://www.tokopedia.com/starcompsolo/philips...

# %%
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3120 entries, 0 to 3119
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nama    3120 non-null   object
#  1   Harga   3120 non-null   int64
#  2   Rating  3120 non-null   object
#  3   Toko    3120 non-null   object
#  4   Lokasi  3120 non-null   object
#  5   URL     3120 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 146.4+ KB
#                                                      Nama         Harga  \
# count                                                3120  3.120000e+03
# unique                                               2863           NaN
# top     Headphone Bluetooth JETE 15 Deep Bass - Garans...           NaN
# freq                                                    7           NaN
# mean                                                  NaN  3.304280e+05
# std                                                   NaN  6.206354e+05
# min                                                   NaN  4.888000e+03
# 25%                                                   NaN  6.957500e+04
# 50%                                                   NaN  1.590000e+05
# 75%                                                   NaN  3.350000e+05
# max                                                   NaN  1.290000e+07
#
#        Rating          Toko         Lokasi  \
# count    3120          3120           3120
# unique     16           926             52
# top       5.0  anugerah-2-1  Jakarta Barat
# freq     1186           161            824
# mean      NaN           NaN            NaN
# std       NaN           NaN            NaN
# min       NaN           NaN            NaN
# 25%       NaN           NaN            NaN
# 50%       NaN           NaN            NaN
# 75%       NaN           NaN            NaN
# max       NaN           NaN            NaN
#
#                                                       URL
# count                                                3120
# unique                                               3114
# top     https://www.tokopedia.com/mixio-audio/special-...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
df.columns = ['nama_produk', 'harga', 'rating', 'nama_toko', 'lokasi_toko', 'url']

# %%
keywords_to_exclude = ['casing', 'silikon', 'cover', 'accessories', 'aksesoris', 'sarung', 'baterai headset', 'pembersih']
df = df[~df['nama_produk'].str.lower().str.contains('|'.join(keywords_to_exclude))]
print(f"Jumlah data setelah filter relevansi: {len(df)}")
# Out:
# Jumlah data setelah filter relevansi: 3064

# %%
before = len(df)
df = df.drop_duplicates(subset=['url'])
after = len(df)
print(f"Duplikat url dihapus: {before - after} baris")
# Out:
# Duplikat url dihapus: 6 baris

# %%
df['timestamp'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df = df.sort_values(by='harga', ascending=True).reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3064 entries, 1 to 3113
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nama_produk  3064 non-null   object
#  1   harga        3064 non-null   int64
#  2   rating       3064 non-null   object
#  3   nama_toko    3064 non-null   object
#  4   lokasi_toko  3064 non-null   object
#  5   url          3064 non-null   object
#  6   timestamp    3064 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 191.5+ KB

# %%
df.head(1)
# Out:
#                                          nama_produk  harga rating nama_toko  \
# 1  BISA COD H681 Headset Macaron U19 Headset warn...   6120    4.7   OS HOME
#
#       lokasi_toko                                                url  \
# 1  Kab. Tangerang  https://www.tokopedia.com/semuagratis/bisa-cod...
#
#             timestamp
# 1 2025-11-17 08:13:50

# %%
output_path = "../data/cleaned/tokopedia_headphone_cleaned.csv"
df.to_csv(output_path, index=False)
print(f"Data bersih disimpan ke {output_path}")
# Out:
# Data bersih disimpan ke ../data/cleaned/tokopedia_headphone_cleaned.csv

# %%
df.head()
# Out:
#                                           nama_produk  harga rating  \
# 1   BISA COD H681 Headset Macaron U19 Headset warn...   6120    4.7
# 3   Local 24h Ship + Headphone Cleaning Pen Portab...   9999    5.0
# 5   HEADSET WARNA WARNI Bluetooth Wireless Earphon...  10399    5.0
# 12  BM025 HF Headset Macaron warna Bass Earphone H...  16250    4.7
# 13  BM025 HF Headset Macaron warna Earphone Headph...  16250    4.6
#
#            nama_toko     lokasi_toko  \
# 1            OS HOME  Kab. Tangerang
# 3         SUPERiCASE  Kab. Tangerang
# 5   Gudang Obral_NEW    Kab. Bandung
# 12           Fypacc1      Kab. Bogor
# 13         surgacell           Bogor
#
#                                                   url           timestamp
# 1   https://www.tokopedia.com/semuagratis/bisa-cod... 2025-11-17 08:13:50
# 3   https://www.tokopedia.com/supericase/local-24h... 2025-11-17 08:13:50
# 5   https://www.tokopedia.com/belanjamurahhematbmh... 2025-11-17 08:13:50
# 12  https://www.tokopedia.com/fypacc1/bm025-hf-hea... 2025-11-17 08:13:50
# 13  https://www.tokopedia.com/surgacell/bm025-hf-h... 2025-11-17 08:13:50
